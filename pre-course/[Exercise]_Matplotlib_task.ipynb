# %% [markdown]
# <a href="https://colab.research.google.com/github/Koar-create/Yang-Repository-CS/blob/main/pre-course/%5BExercise%5D_Matplotlib_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Exercise] Matplotlib task.ipynb**
#
# Author: Zhixian Yang
#
# Email: yangzhx28@mail2.sysu.edu.cn
#
# GitHub: https://github.com/koar-create
#
# Date created: July 14th, 2023
#
# Last modified: July 14th, 2023
#
# <br><br>
#
# ---
#
# <br><br>
#
# ## **Description**
# This document is a Jupyter Notebook designed for an exercise derived from the "Computational Tools for Climate Science 2023" course offered by Climatematch Academy. The code presented here comprises a combination of materials provided in the course and code obtained from online sources.

# %% [markdown]
# # **task 1:**
#
# ---
#
# **Description:** Here will be only one task.
#
# Your sample data is given with this code
# ```python
# x = np.linspace(0, 2, 100)
# ```
# Please create the plot that would look like the one in the attachment 🙂

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots(figsize=(6, 3))
p1, p2, p3 = ax.plot(x, x, label='linear'), ax.plot(x, x**3, label='cubic'), ax.plot(x, x**4, label='quadratic')
ax.legend(loc='upper left')
ax.set_xlabel('x label'), ax.set_ylabel('y label'), ax.set_title('Simple Plot')
plt.show()
